# %% [markdown]
# ## Loading data from a file

# %%
import pandas as pd

dataFile = pd.read_csv('CSV_Files/1_24_2024.csv')
dataFile

# Good rules for handling data
# 1. Look at your data before loading
# 2. When you are saving data, make sure there is a key!
#    * columns are labeled and interpreted
# Out:
#    1  Parker   98   History
# 0  2   Enoch   95   English
# 1  3   Ethan  100   Science
# 2  4    Seth   92      Math
# 3  5   Dusty   96      P.E.

# %%
dataFile = pd.read_csv('CSV_Files/1_24_2024.csv', header=None)
dataFile.columns = ['Id', 'Name', 'Grade', 'Class']
dataFile

# use skiprows=Num to skip that amount of rows at the start of the file
# use dilimiter to change what the csv file is breaking on instead of just a comma
# Out:
#    Id     Name  Grade     Class
# 0   1   Parker     98   History
# 1   2    Enoch     95   English
# 2   3    Ethan    100   Science
# 3   4     Seth     92      Math
# 4   5    Dusty     96      P.E.

# %% [markdown]
# ## Load data from a file on the web

# %%
salaries = pd.read_csv('https://raw.githubusercontent.com/drolsonmi/math3080/main/Datasets/data_science_salaries.csv')
salaries.head(7)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0       2023               MI              FT  AWS Data Architect  258000
# 1       2023               SE              FT      Data Scientist  225000
# 2       2023               SE              FT      Data Scientist  156400
# 3       2023               SE              FT       Data Engineer  190000
# 4       2023               SE              FT       Data Engineer  150000
# 5       2023               SE              FT      Data Scientist  196000
# 6       2023               SE              FT      Data Scientist  121000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         258000                 US           100
# 1             USD         225000                 US             0
# 2             USD         156400                 US             0
# 3             USD         190000                 US           100
# ...

# %% [markdown]
# ## Load data from an excel file

# %%
grades = pd.read_excel('CSV_Files/1_24_2024.xlsx')
grades
# Out:
#    Id    Name  Grade    Class
# 0   1  Parker     98  History
# 1   2   Enoch     95  English
# 2   3   Ethan    100  Science
# 3   4    Seth     92     Math
# 4   5   Dusty     96     P.E.

# %% [markdown]
# ## Load data from an HTML webpage (Web Scraping)

# %%
failed_banks = pd.read_html('https://raw.githubusercontent.com/wesm/pydata-book/3rd-edition/examples/fdic_failed_bank_list.html')
failed_banks[0].head(10)
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
# 5        Hometown National Bank         Longview  WA  35156
# 6           The Bank of Georgia   Peachtree City  GA  35259
# 7                  Premier Bank           Denver  CO  34112
# 8                Edgebrook Bank          Chicago  IL  57772
# 9        Doral Bank  En Espanol         San Juan  PR  32102
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# ...
