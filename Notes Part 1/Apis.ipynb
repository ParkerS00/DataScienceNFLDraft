# %% [markdown]
# ## Api's

# %%
import pandas as pd
import requests

api_url = "https://api.yelp.com/v3/businesses/search"

authorization = {
    'Authorization' : 'Bearer mI7TeywsMoihEuAgUYcbSDsicojTD2Qbyw68UoSEXQec79BBJfrS3CWLo-GeE2XW8gpDflIQ-tKZAEHXyKevv5nW3LYjfSgfyiN3cnt0CVPZFP6ZyKlMw1atGtSzZXYx'
}

search_parameters = {
    'term' : 'restaurants',
    'location' : 'Ephraim, UT',
    'limit' : 30
}

# %%
response = requests.get(api_url, headers=authorization, params=search_parameters)

# Generally a good idea to check for HTTP error
response.raise_for_status()

response
response.text
# Out:
# '{"businesses": [{"id": "MdpvieSSi2Z4pREUlYnl7w", "alias": "solid-rock-cafe-ephraim", "name": "Solid Rock Cafe", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/t18VpatgR6oKNORma1BRCg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/solid-rock-cafe-ephraim?adjust_creative=kQKF0v805BM3aGbJaVsRmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kQKF0v805BM3aGbJaVsRmg", "review_count": 15, "categories": [{"alias": "cafes", "title": "Cafes"}, {"alias": "coffee", "title": "Coffee & Tea"}, {"alias": "bagels", "title": "Bagels"}], "rating": 4.5, "coordinates": {"latitude": 39.3597646, "longitude": -111.5842886}, "transactions": [], "price": "$", "location": {"address1": "96 E Center St", "address2": "", "address3": "", "city": "Ephraim", "zip_code": "84627", "country": "US", "state": "UT", "display_address": ["96 E Center St", "Ephraim, UT 84627"]}, "phone": "+14352830178", "display_phone": "(435) 283-0178", "distance": 364.1014950734865}, {"id": "WIWF
# ...

# %%
data = response.json()
data
# Out:
# {'businesses': [{'id': 'MdpvieSSi2Z4pREUlYnl7w',
#    'alias': 'solid-rock-cafe-ephraim',
#    'name': 'Solid Rock Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t18VpatgR6oKNORma1BRCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/solid-rock-cafe-ephraim?adjust_creative=kQKF0v805BM3aGbJaVsRmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kQKF0v805BM3aGbJaVsRmg',
#    'review_count': 15,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.3597646, 'longitude': -111.5842886},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '96 E Center St',
#     'address2': '',
#     'address3': '',
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
# ...

# %%
list(data)

data['businesses']
restaurants = pd.DataFrame(data['businesses'])
restaurants.head()
# Out:
#                        id                            alias  \
# 0  MdpvieSSi2Z4pREUlYnl7w          solid-rock-cafe-ephraim
# 1  WIWFHMIm4Ge_vf5_6XlwJw                abundance-ephraim
# 2  qIwElGbCtu5-Cv-20GQDAA     roys-pizza-and-pasta-ephraim
# 3  OfPUpvh77irKr2pfEYVEWg  joses-cafe-mexican-food-ephraim
# 4  xmT_KLJ2Fh9o7ozWF-s4lQ          the-malt-shop-ephraim-2
#
#                        name  \
# 0           Solid Rock Cafe
# 1                 Abundance
# 2       Roy's Pizza & Pasta
# 3  Jose's Cafe Mexican Food
# 4             The Malt Shop
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/t18Vpa...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/XRQwzY...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/CD90xe...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/MH48Mo...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/cpbfea...      False
#
# ...

# %%
restaurants['is_closed'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: is_closed, dtype: bool>

# %%
restaurants['categories']
# Out:
# 0     [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...
# 1     [{'alias': 'sandwiches', 'title': 'Sandwiches'...
# 2     [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 3            [{'alias': 'mexican', 'title': 'Mexican'}]
# 4     [{'alias': 'icecream', 'title': 'Ice Cream & F...
# 5            [{'alias': 'chinese', 'title': 'Chinese'}]
# 6            [{'alias': 'mexican', 'title': 'Mexican'}]
# 7     [{'alias': 'bowling', 'title': 'Bowling'}, {'a...
# 8     [{'alias': 'foodstands', 'title': 'Food Stands'}]
# 9     [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...
# 10    [{'alias': 'sandwiches', 'title': 'Sandwiches'...
# 11    [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...
# 12    [{'alias': 'convenience', 'title': 'Convenienc...
# 13    [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 14               [{'alias': 'pizza', 'title': 'Pizza'}]
# 15    [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...
# Name: categories, dtype: object

# %%
restaurants['name'].str.contains('Pizza')
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# Name: name, dtype: bool

# %%
restaurants[restaurants['name'].str.contains('Pizza')]
# Out:
#                         id                         alias  \
# 2   qIwElGbCtu5-Cv-20GQDAA  roys-pizza-and-pasta-ephraim
# 13  V_iq0GXQOFG-ubl8cDbppw  little-caesars-pizza-ephraim
#
#                     name                                          image_url  \
# 2    Roy's Pizza & Pasta  https://s3-media2.fl.yelpcdn.com/bphoto/CD90xe...
# 13  Little Caesars Pizza  https://s3-media2.fl.yelpcdn.com/bphoto/1LqaOt...
#
#     is_closed                                                url  \
# 2       False  https://www.yelp.com/biz/roys-pizza-and-pasta-...
# 13      False  https://www.yelp.com/biz/little-caesars-pizza-...
#
#     review_count                                         categories  rating  \
# 2             61  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 13            10  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.0
#
#                                           coordinates transactions price  \
# ...

# %%
restaurants[restaurants['name'].str.contains('Arby')]
# Out:
#                         id          alias    name image_url  is_closed  \
# 15  O5gnlAKccLt7rfAW6-KDxw  arbys-ephraim  Arby's                False
#
#                                                   url  review_count  \
# 15  https://www.yelp.com/biz/arbys-ephraim?adjust_...             0
#
#                                            categories  rating  \
# 15  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     0.0
#
#                                           coordinates transactions price  \
# 15  {'latitude': 39.37366766725062, 'longitude': -...           []   NaN
#
#                                              location         phone  \
# 15  {'address1': '791 N 50 E', 'address2': '', 'ad...  +14352834002
#
#      display_phone     distance
# 15  (435) 283-4002  1794.134265

# %%
# from pandas.io.json import json_normalize

restaurants_flat = pd.json_normalize(data['businesses'], sep='_', record_path='categories', meta=['name', 'rating'])
restaurants_flat
# Out:
#               alias                      title                           name  \
# 0             cafes                      Cafes                Solid Rock Cafe
# 1            coffee               Coffee & Tea                Solid Rock Cafe
# 2            bagels                     Bagels                Solid Rock Cafe
# 3        sandwiches                 Sandwiches                      Abundance
# 4             salad                      Salad                      Abundance
# 5              soup                       Soup                      Abundance
# 6           italian                    Italian            Roy's Pizza & Pasta
# 7             pizza                      Pizza            Roy's Pizza & Pasta
# 8        sandwiches                 Sandwiches            Roy's Pizza & Pasta
# 9           mexican                    Mexican       Jose's Cafe Mexican Food
# 10         icecream  Ice Cream & Frozen Yogurt                  The Malt Shop
# ...

# %%
restaurants_flat[restaurants_flat['title'] == 'Pizza']
# Out:
#     alias  title                  name rating
# 7   pizza  Pizza   Roy's Pizza & Pasta    4.5
# 28  pizza  Pizza  Little Caesars Pizza    3.0
# 30  pizza  Pizza         Papa Murphy's    2.5
