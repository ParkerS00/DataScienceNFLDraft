# %% [markdown]
# # API's
# - Dictionary
# - Date Time Formats
# - Scaling
# - Graph
#
# # Stocks
# 1. Open
# 2. High
# 3. Low
# 4. Close
# 5. Volume

# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 

data = pd.read_csv("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=IBM&outputsize=compact&apikey=ENIPDF3XPHW9IUUE&datatype=csv", delimiter=',')
data
# Out:
#      timestamp    open      high     low   close  adjusted_close   volume  \
# 0   2024-02-27  184.16  185.1300  182.62  184.87      184.870000  3641378
# 1   2024-02-26  185.60  186.1250  184.06  184.13      184.130000  4620815
# 2   2024-02-23  184.90  186.4550  184.57  185.72      185.720000  3433800
# 3   2024-02-22  182.45  184.5500  181.93  184.21      184.210000  5078398
# 4   2024-02-21  182.56  183.0300  178.75  179.70      179.700000  4728473
# ..         ...     ...       ...     ...     ...             ...      ...
# 95  2023-10-10  142.60  143.4150  141.72  142.11      139.265113  3015784
# 96  2023-10-09  142.30  142.4000  140.68  142.20      139.353312  2354396
# 97  2023-10-06  141.40  142.9400  140.11  142.03      139.186715  3511347
# 98  2023-10-05  140.90  141.7000  140.19  141.52      138.686924  3223910
# 99  2023-10-04  140.37  141.2004  139.99  141.07      138.245933  2637779
#
#     dividend_amount  split_coefficient
# 0               0.0                1.0
# ...

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   timestamp          100 non-null    object
#  1   open               100 non-null    float64
#  2   high               100 non-null    float64
#  3   low                100 non-null    float64
#  4   close              100 non-null    float64
#  5   adjusted_close     100 non-null    float64
#  6   volume             100 non-null    int64
#  7   dividend_amount    100 non-null    float64
#  8   split_coefficient  100 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 7.2+ KB
#              open        high         low      close  adjusted_close  \
# count  100.000000  100.000000  100.000000  100.00000      100.000000
# mean   161.178700  162.425144  160.181509  161.43210      159.795511
# ...

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

ax.scatter(data['open'], data['close'], c='Orange')

plt.title('Low of the Stock vs the High of the Stock')
plt.xlabel('Low of stock')
plt.ylabel('High of stock')

plt.show()

# %%
Google = pd.read_csv("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=GOOGL&outputsize=compact&apikey=ENIPDF3XPHW9IUUE&datatype=csv", delimiter=',')
Google
# Out:
#      timestamp    open     high      low   close  adjusted_close    volume  \
# 0   2024-02-27  138.02  139.250  137.090  138.88          138.88  33099190
# 1   2024-02-26  142.14  142.440  137.390  137.57          137.57  53641795
# 2   2024-02-23  143.67  144.680  143.430  143.96          143.96  19493752
# 3   2024-02-22  144.93  145.000  142.800  144.09          144.09  27191892
# 4   2024-02-21  141.45  142.690  140.675  142.55          142.55  23315687
# ..         ...     ...      ...      ...     ...             ...       ...
# 95  2023-10-10  138.50  139.720  137.330  138.06          138.06  27786613
# 96  2023-10-09  136.94  138.940  135.610  138.42          138.42  19278070
# 97  2023-10-06  134.01  138.155  134.010  137.58          137.58  27597598
# 98  2023-10-05  135.07  135.490  133.450  135.07          135.07  19832615
# 99  2023-10-04  132.79  135.570  132.530  135.24          135.24  26752295
#
#     dividend_amount  split_coefficient
# ...
